# %%
import matplotlib.pyplot as plt
import random, time
from PIL import Image
from wfc import *

s = time.time()
model = WFCModel('sample/Font.png', 
                 (5, 5), 
                 flip_horizontal=True, 
                 flip_vertical=False, 
                 rotate=False)
print(time.time()-s)

print(len(model.tileset))
print('middle:', len(model.tileset_middle))
for dir in ['top', 'bottom', 'left', 'right']:
    print(f'{dir}:', len(model.tileset_edge[dir]))
# Out:
# model initialization finised
# 0.04399728775024414
# 302
# middle: 302
# top: 0
# bottom: 0
# left: 0
# right: 0

# %%
show_process = 50
show_prop = False
seed = 72548558

#random.seed(seed)

s = time.time()
result = model.generate((64, 16), show_process=show_process, show_prop=show_prop)
print(time.time() - s)

if result:
    img = model.overwrite_tile()
    if not show_process:
        plt.imshow(img)
        plt.axis('off')
        plt.show()
    print(img)

else:
    print("TT_TT")

# %%
model.view_performance()
model.view_log()
# Out:
# Propagate : 177.6444227695465s
# Visualize : 6.7464845180511475s
