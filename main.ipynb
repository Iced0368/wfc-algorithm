# %%
import matplotlib.pyplot as plt
import random, time
from PIL import Image
from wfc import *

s = time.time()
model = WFCModel('sample/Qud.png', 
                 (3, 3), 
                 flip_horizontal=False, 
                 flip_vertical=False, 
                 rotate=True)
print(time.time()-s)

print(len(model.tileset))
print('middle:', len(model.tileset_middle))
for dir in ['top', 'bottom', 'left', 'right']:
    print(f'{dir}:', len(model.tileset_edge[dir]))
# Out:
# model initialization finised
# 0.014682292938232422
# 100
# middle: 92
# top: 2
# bottom: 2
# left: 2
# right: 2

# %%
show_process = 50
show_prop = False
seed = 72548558

#random.seed(seed)

s = time.time()
result = model.generate((64, 64), show_process=show_process, show_prop=show_prop)
print(time.time() - s)

if result:
    img = model.overwrite_tile()
    if not show_process:
        plt.imshow(img)
        plt.axis('off')
        plt.show()
    print(img)

else:
    print("TT_TT")
# Out:
# 3.7731423377990723
# <PIL.Image.Image image mode=RGB size=64x64 at 0x14FF3FF87C0>

# %%
model.view_performance()
model.view_log()
# Out:
# Propagate : 4.950018405914307s
# Visualize : 1.121589183807373s
